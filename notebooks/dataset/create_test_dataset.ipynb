# %%
from datasets import load_dataset, DatasetDict, Audio, ClassLabel

# %%
SAMPLING_RATE = 16000
labels = ClassLabel(names=["other", "drone"])

# %%
def load_and_prepare_hf_dataset(repo_name, split="test"):
    ds = load_dataset(repo_name, split=split)
    ds = ds.cast_column("audio", Audio(sampling_rate=SAMPLING_RATE))
    return ds

def load_and_prepare_audiofolder(path):
    ds = load_dataset("audiofolder", data_dir=path)["train"]
    ds = ds.cast_column("audio", Audio(sampling_rate=SAMPLING_RATE))
    return ds

def swap_labels(ds):
    def _swap(example):
        example["label"] = 1 - example["label"]
        return example
    return ds.map(_swap)

# %%
# -----------------------------
# Load datasets
# -----------------------------
ds_drone_test = load_and_prepare_hf_dataset("Usernameeeeee/drone_test")
ds_drone_test = ds_drone_test.remove_columns(["filename"])
ds_drone_test_2 = load_and_prepare_hf_dataset("Usernameeeeee/drone_test_2")
ds_drone_test_2 = ds_drone_test_2.remove_columns(["filename"])

ds_mic_parabole = load_and_prepare_audiofolder(
    "../../data/test/mic_parabole"
)
ds_parabole2 = load_and_prepare_audiofolder(
    "../../data/test/parabole2"
)
ds_parabole3 = load_and_prepare_audiofolder(
    "../../data/raw/test/28-01-2026/drone1"
)
ds_parabole4 = load_and_prepare_audiofolder(
    "../../data/raw/test/28-01-2026/drone2"
)
ds_parabole5 = load_and_prepare_audiofolder(
    "../../data/raw/test/28-01-2026/drone3"
)
ds_parabole6 = load_and_prepare_audiofolder(
    "../../data/raw/test/28-01-2026/drone4"
)
ds_parabole7 = load_and_prepare_audiofolder(
    "/home/pierre/Downloads/hibou_test/hibou_dataset"
)
print(ds_parabole7)
# Out:
# Dataset({
#     features: ['audio', 'label'],
#     num_rows: 7953
# })

# %%
ds_drone_test = swap_labels(ds_drone_test)
ds_drone_test_2 = swap_labels(ds_drone_test_2)
ds_mic_parabole = swap_labels(ds_mic_parabole)
ds_parabole2 = swap_labels(ds_parabole2)
ds_parabole3 = swap_labels(ds_parabole3)
ds_parabole4 = swap_labels(ds_parabole4)
ds_parabole5 = swap_labels(ds_parabole5)
ds_parabole6 = swap_labels(ds_parabole6)
ds_parabole7 = swap_labels(ds_parabole7)

ds_drone_test = ds_drone_test.cast_column(
    "label",
    labels
)
ds_drone_test_2 = ds_drone_test_2.cast_column(
    "label",
    labels
)
ds_mic_parabole = ds_mic_parabole.cast_column(
    "label",
    labels
)
ds_parabole2 = ds_parabole2.cast_column(
    "label",
    labels
)
ds_parabole3 = ds_parabole3.cast_column(
    "label",
    labels
)
ds_parabole4 = ds_parabole4.cast_column(
    "label",
    labels
)
ds_parabole5 = ds_parabole5.cast_column(
    "label",
    labels
)
ds_parabole6 = ds_parabole6.cast_column(
    "label",
    labels
)
ds_parabole7 = ds_parabole7.cast_column(
    "label",
    labels
)
# Out:
# Map: 100%|██████████| 7953/7953 [00:00<00:00, 58165.85 examples/s]
# Casting the dataset: 100%|██████████| 7953/7953 [00:00<00:00, 259105.95 examples/s]

# %%
all_tests = DatasetDict({
    "drone_test": ds_drone_test,
    "drone_test_2": ds_drone_test_2,
    "parabole1": ds_mic_parabole,
    "parabole2": ds_parabole2,
    "parabole3": ds_parabole3,
    "parabole4": ds_parabole4,
    "parabole5": ds_parabole5,
    "parabole6": ds_parabole6,
    "parabole7": ds_parabole7,
})

# %%
all_tests
# Out:
# DatasetDict({
#     drone_test: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 893
#     })
#     drone_test_2: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 2805
#     })
#     parabole1: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 123
#     })
#     parabole2: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 85
#     })
#     parabole3: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 275
#     })
#     parabole4: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 157
#     })
#     parabole5: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 83
#     })
#     parabole6: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 613
#     })
#     parabole7: Dataset({
#         features: ['audio', 'label'],
#         num_rows: 7953
#     })
# })

# %%
all_tests.push_to_hub("Hibou-Foundation/all_tests_ds_3")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map: 100%|██████████| 893/893 [00:00<00:00, 11928.35 examples/s]
#
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 47.53ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████| 28.3MB / 28.3MB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:01<00:00,  1.59s/ shards]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map:   0%|          | 0/2805 [00:00<?, ? examples/s]
# Map: 100%|██████████| 2805/2805 [00:00<00:00, 8177.46 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00,  4.66ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████| 74.1MB / 74.1MB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:02<00:00,  2.26s/ shards]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map: 100%|██████████| 123/123 [00:00<00:00, 2821.90 examples/s]
#
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 59.41ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████| 6.62MB / 6.62MB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:01<00:00,  1.00s/ shards]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map: 100%|██████████| 85/85 [00:00<00:00, 2078.03 examples/s]
#
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 89.62ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████| 4.67MB / 4.67MB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  1.12 shards/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map: 100%|██████████| 275/275 [00:00<00:00, 3931.36 examples/s]
#
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 220.57ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████| 4.38MB / 4.38MB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  1.09 shards/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map: 100%|██████████| 157/157 [00:00<00:00, 4144.62 examples/s]
#
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 484.05ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████| 2.52MB / 2.52MB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:01<00:00,  1.02s/ shards]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map: 100%|██████████| 83/83 [00:00<00:00, 3827.72 examples/s]
#
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 757.23ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████| 1.33MB / 1.33MB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:00<00:00,  1.25 shards/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Map:   0%|          | 0/613 [00:00<?, ? examples/s]
# Map: 100%|██████████| 613/613 [00:00<00:00, 4361.45 examples/s]
#
# Creating parquet from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 180.30ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████| 9.83MB / 9.83MB,  0.00B/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# Uploading the dataset shards: 100%|██████████| 1/1 [00:01<00:00,  1.23s/ shards]
# Uploading the dataset shards:   0%|          | 0/4 [00:00<?, ? shards/s]
# Map:   0%|          | 0/1989 [00:00<?, ? examples/s]
# Map:  26%|██▌       | 520/1989 [00:00<00:01, 956.91 examples/s]
# Map:  52%|█████▏    | 1040/1989 [00:01<00:01, 880.02 examples/s]
# Map:  78%|███████▊  | 1560/1989 [00:01<00:00, 776.85 examples/s]
# Map: 100%|██████████| 1989/1989 [00:02<00:00, 870.03 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:  25%|██▌       | 1/4 [00:00<00:00,  8.63ba/s]
# Creating parquet from Arrow format:  50%|█████     | 2/4 [00:00<00:00,  9.11ba/s]
# Creating parquet from Arrow format:  75%|███████▌  | 3/4 [00:00<00:00,  8.78ba/s]
# Creating parquet from Arrow format: 100%|██████████| 4/4 [00:00<00:00,  8.46ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████|  382MB /  382MB,  241MB/s
# Processing Files (1 / 1): 100%|██████████|  382MB /  382MB,  181MB/s
# New Data Upload: 100%|██████████|  421kB /  421kB,  263kB/s
# Uploading the dataset shards:  25%|██▌       | 1/4 [00:09<00:27,  9.16s/ shards]
# Map:   0%|          | 0/1988 [00:00<?, ? examples/s]
# Map:  26%|██▌       | 520/1988 [00:00<00:00, 1750.53 examples/s]
# Map:  52%|█████▏    | 1040/1988 [00:00<00:00, 1840.45 examples/s]
# Map:  78%|███████▊  | 1560/1988 [00:00<00:00, 1840.84 examples/s]
# Map: 100%|██████████| 1988/1988 [00:01<00:00, 1826.57 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:  25%|██▌       | 1/4 [00:00<00:00,  9.51ba/s]
# Creating parquet from Arrow format: 100%|██████████| 4/4 [00:00<00:00, 11.10ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████|  382MB /  382MB,  241MB/s
# Processing Files (1 / 1): 100%|██████████|  382MB /  382MB,  181MB/s
# New Data Upload: 100%|██████████|  296kB /  296kB,  185kB/s
# Uploading the dataset shards:  50%|█████     | 2/4 [00:16<00:16,  8.21s/ shards]
# Map:   0%|          | 0/1988 [00:00<?, ? examples/s]
# Map:  26%|██▌       | 520/1988 [00:00<00:00, 1734.23 examples/s]
# Map:  52%|█████▏    | 1040/1988 [00:00<00:00, 1582.05 examples/s]
# Map:  78%|███████▊  | 1560/1988 [00:01<00:00, 1224.11 examples/s]
# Map: 100%|██████████| 1988/1988 [00:01<00:00, 1201.77 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:  25%|██▌       | 1/4 [00:00<00:00,  9.34ba/s]
# Creating parquet from Arrow format:  50%|█████     | 2/4 [00:00<00:00,  7.63ba/s]
# Creating parquet from Arrow format:  75%|███████▌  | 3/4 [00:00<00:00,  7.42ba/s]
# Creating parquet from Arrow format: 100%|██████████| 4/4 [00:00<00:00,  7.25ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████|  525MB /  525MB,  271MB/s
# Processing Files (1 / 1): 100%|██████████|  525MB /  525MB,  216MB/s
# New Data Upload: 100%|██████████|  401kB /  401kB,  201kB/s
# Uploading the dataset shards:  75%|███████▌  | 3/4 [00:26<00:09,  9.15s/ shards]
# Map:   0%|          | 0/1988 [00:00<?, ? examples/s]
# Map:  26%|██▌       | 520/1988 [00:00<00:01, 1246.96 examples/s]
# Map:  52%|█████▏    | 1040/1988 [00:00<00:00, 1234.97 examples/s]
# Map:  78%|███████▊  | 1560/1988 [00:01<00:00, 869.10 examples/s]
# Map: 100%|██████████| 1988/1988 [00:02<00:00, 957.86 examples/s]
#
# Creating parquet from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:  25%|██▌       | 1/4 [00:00<00:00,  4.60ba/s]
# Creating parquet from Arrow format:  50%|█████     | 2/4 [00:00<00:00,  4.88ba/s]
# Creating parquet from Arrow format:  75%|███████▌  | 3/4 [00:00<00:00,  4.78ba/s]
# Creating parquet from Arrow format: 100%|██████████| 4/4 [00:00<00:00,  4.94ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# Processing Files (1 / 1): 100%|██████████|  760MB /  760MB,  304MB/s
# Processing Files (1 / 1): 100%|██████████|  760MB /  760MB,  239MB/s
# New Data Upload: 100%|██████████|  441kB /  441kB,  158kB/s
# Uploading the dataset shards: 100%|██████████| 4/4 [00:41<00:00, 10.25s/ shards]
# CommitInfo(commit_url='https://huggingface.co/datasets/Hibou-Foundation/all_tests_ds_3/commit/1151764d860ddc1c7051ef8fcb25b301aed3e073', commit_message='Upload dataset', commit_description='', oid='1151764d860ddc1c7051ef8fcb25b301aed3e073', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Hibou-Foundation/all_tests_ds_3', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Hibou-Foundation/all_tests_ds_3'), pr_revision=None, pr_num=None)
